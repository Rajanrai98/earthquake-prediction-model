# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn

# %%
data = pd.read_csv(r"C:\Users\user\Downloads\earthquake data.csv")

# %%
data
# Out:
#             Date & Time  Latitude  Longitude  Depth  Magnitude  \
# 0      11/21/2023 17:43    31.592   -104.549      3        2.7
# 1      11/21/2023 17:31   -24.200    -67.580    198        4.0
# 2      11/21/2023 17:27    31.647   -104.017      5        2.9
# 3      11/21/2023 17:01    46.345     13.601      0        0.8
# 4      11/21/2023 16:56    -4.320    130.810     10        3.3
# ...                 ...       ...        ...    ...        ...
# 53534    5/14/2023 9:50    18.080   -103.270      7        3.5
# 53535    5/14/2023 9:49    11.520    141.620     10        5.1
# 53536    5/14/2023 9:48    19.400   -155.240      2        2.2
# 53537    5/14/2023 9:28    15.890    -93.520    106        3.9
# 53538    5/14/2023 9:27   -23.970    -67.460    240        3.7
#
#                       Lands     Country
# 0                   WESTERN       TEXAS
# 1                    SALTA,   ARGENTINA
# 2                   WESTERN       TEXAS
# 3                  SLOVENIA    SLOVENIA
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53539 entries, 0 to 53538
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date & Time  53539 non-null  object
#  1   Latitude     53539 non-null  float64
#  2   Longitude    53539 non-null  float64
#  3   Depth        53539 non-null  int64
#  4   Magnitude    53539 non-null  float64
#  5   Lands        53539 non-null  object
#  6   Country      53539 non-null  object
# dtypes: float64(3), int64(1), object(3)
# memory usage: 2.9+ MB

# %%
data.isnull().sum()
# Out:
# Date & Time    0
# Latitude       0
# Longitude      0
# Depth          0
# Magnitude      0
# Lands          0
# Country        0
# dtype: int64

# %%
data.shape
# Out:
# (53539, 7)

# %%
data.columns
# Out:
# Index(['Date & Time', 'Latitude', 'Longitude', 'Depth', 'Magnitude', 'Lands',
#        'Country'],
#       dtype='object')

# %%
data.skew()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_28716\1188251951.py:1: FutureWarning: The default value of numeric_only in DataFrame.skew is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.skew()
# Latitude    -0.720174
# Longitude    0.273161
# Depth        4.529910
# Magnitude    0.299351
# dtype: float64

# %%
data.kurtosis()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_28716\2361870383.py:1: FutureWarning: The default value of numeric_only in DataFrame.kurt is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.kurtosis()
# Latitude     -0.112695
# Longitude    -0.931211
# Depth        27.462551
# Magnitude     0.261619
# dtype: float64

# %%
data.describe()
# Out:
#            Latitude     Longitude         Depth     Magnitude
# count  53539.000000  53539.000000  53539.000000  53539.000000
# mean      21.120630    -15.421862     35.799959      2.962569
# std       25.645429     93.129891     67.580186      0.893910
# min      -65.899000   -179.992000     -4.000000     -0.700000
# 25%        8.485000    -94.570000      6.000000      2.300000
# 50%       29.320000     -8.373000     10.000000      2.900000
# 75%       38.470000     37.460000     32.000000      3.500000
# max       85.330000    180.000000    750.000000      7.700000

# %%
data.corr()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_28716\2627137660.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#            Latitude  Longitude     Depth  Magnitude
# Latitude   1.000000  -0.136270 -0.393834  -0.428230
# Longitude -0.136270   1.000000  0.008043   0.130760
# Depth     -0.393834   0.008043  1.000000   0.299489
# Magnitude -0.428230   0.130760  0.299489   1.000000

# %%
sn.heatmap(data.corr() , annot = True , cmap = "tab20")
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_28716\1324518194.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sn.heatmap(data.corr() , annot = True , cmap = "tab20")
# <Axes: >

# %%
data.head()
# Out:
#         Date & Time  Latitude  Longitude  Depth  Magnitude     Lands  \
# 0  11/21/2023 17:43    31.592   -104.549      3        2.7   WESTERN
# 1  11/21/2023 17:31   -24.200    -67.580    198        4.0    SALTA,
# 2  11/21/2023 17:27    31.647   -104.017      5        2.9   WESTERN
# 3  11/21/2023 17:01    46.345     13.601      0        0.8  SLOVENIA
# 4  11/21/2023 16:56    -4.320    130.810     10        3.3     BANDA
#
#      Country
# 0      TEXAS
# 1  ARGENTINA
# 2      TEXAS
# 3   SLOVENIA
# 4        SEA

# %% [markdown]
# ## Univariate analysis

# %%
for i in ("Latitude","Longitude","Magnitude","Depth"):
    data[i].plot(kind = "hist")
    plt.title(i)
    plt.grid()
    plt.show()

# %%
for i in ("Latitude","Longitude","Magnitude","Depth"):
          sn.distplot(data[i] , color = 'red')
          plt.title(i)
          plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_28716\2289539171.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(data[i] , color = 'red')
# C:\Users\user\AppData\Local\Temp\ipykernel_28716\2289539171.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %% [markdown]
# ## bivariate analysis

# %%
sn.jointplot(x = "Longitude" , y = "Magnitude" , data = data , color = 'red' )

# %%
sn.scatterplot(x = "Depth" , y = "Magnitude" , data = data , color = 'red' )
# Out:
# <Axes: xlabel='Depth', ylabel='Magnitude'>

# %%
sn.jointplot(x   = "Depth" , y = "Magnitude" , data = data , kind = 'kde')

# %%
data
# Out:
#             Date & Time  Latitude  Longitude  Depth  Magnitude  \
# 0      11/21/2023 17:43    31.592   -104.549      3        2.7
# 1      11/21/2023 17:31   -24.200    -67.580    198        4.0
# 2      11/21/2023 17:27    31.647   -104.017      5        2.9
# 3      11/21/2023 17:01    46.345     13.601      0        0.8
# 4      11/21/2023 16:56    -4.320    130.810     10        3.3
# ...                 ...       ...        ...    ...        ...
# 53534    5/14/2023 9:50    18.080   -103.270      7        3.5
# 53535    5/14/2023 9:49    11.520    141.620     10        5.1
# 53536    5/14/2023 9:48    19.400   -155.240      2        2.2
# 53537    5/14/2023 9:28    15.890    -93.520    106        3.9
# 53538    5/14/2023 9:27   -23.970    -67.460    240        3.7
#
#                       Lands     Country
# 0                   WESTERN       TEXAS
# 1                    SALTA,   ARGENTINA
# 2                   WESTERN       TEXAS
# 3                  SLOVENIA    SLOVENIA
# ...

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import RFE
from sklearn.feature_selection import SelectKBest,chi2

# %%
le = LabelEncoder()
data_en = data[["Lands","Country","Date & Time"]].apply(le.fit_transform)

# %%
data_en
# Out:
#        Lands  Country  Date & Time
# 0        708      163        11203
# 1        552       10        11202
# 2        708      163        11201
# 3        584      149        11200
# 4         47      146        11199
# ...      ...      ...          ...
# 53534    481       99        13417
# 53535    632      101        13416
# 53536    226       60        13415
# 53537     99       99        13414
# 53538     18       35        13413
#
# [53539 rows x 3 columns]

# %%
data = data.drop(['Lands','Country','Date & Time'] , axis = 1)

# %%
data
# Out:
#        Latitude  Longitude  Depth  Magnitude
# 0        31.592   -104.549      3        2.7
# 1       -24.200    -67.580    198        4.0
# 2        31.647   -104.017      5        2.9
# 3        46.345     13.601      0        0.8
# 4        -4.320    130.810     10        3.3
# ...         ...        ...    ...        ...
# 53534    18.080   -103.270      7        3.5
# 53535    11.520    141.620     10        5.1
# 53536    19.400   -155.240      2        2.2
# 53537    15.890    -93.520    106        3.9
# 53538   -23.970    -67.460    240        3.7
#
# [53539 rows x 4 columns]

# %%
data = pd.concat([data , data_en] , axis = 1)

# %%
data
# Out:
#        Latitude  Longitude  Depth  Magnitude  Lands  Country  Date & Time
# 0        31.592   -104.549      3        2.7    708      163        11203
# 1       -24.200    -67.580    198        4.0    552       10        11202
# 2        31.647   -104.017      5        2.9    708      163        11201
# 3        46.345     13.601      0        0.8    584      149        11200
# 4        -4.320    130.810     10        3.3     47      146        11199
# ...         ...        ...    ...        ...    ...      ...          ...
# 53534    18.080   -103.270      7        3.5    481       99        13417
# 53535    11.520    141.620     10        5.1    632      101        13416
# 53536    19.400   -155.240      2        2.2    226       60        13415
# 53537    15.890    -93.520    106        3.9     99       99        13414
# 53538   -23.970    -67.460    240        3.7     18       35        13413
#
# [53539 rows x 7 columns]

# %%
x = data.drop(["Magnitude"] , axis = 1)
y = data["Magnitude"]

# %%
x_train , x_test , y_train , y_test = train_test_split( x, y , test_size = 0.20 , random_state = 42)

# %%
x_train.shape , x_test.shape
# Out:
# ((42831, 6), (10708, 6))

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
x_train
# Out:
# array([[ 0.8206194 ,  1.70289269,  0.43435515, -0.628993  ,  0.74427104,
#         -0.32718167],
#        [-1.6166335 ,  1.45033289, -0.38219055,  1.64958987, -1.71778646,
#         -0.81723337],
#        [-0.86875128,  1.45979447, -0.38219055,  1.32930714, -0.60784251,
#         -0.53617327],
#        ...,
#        [ 0.99205461, -0.65105287, -0.38219055,  1.23322232, -1.35453208,
#          0.59591761],
#        [ 0.60550568,  0.01391377, -0.53065341, -1.42512436,  0.82499424,
#         -0.99821798],
#        [-1.66191238, -0.58519809,  0.12258316,  1.40251462, -1.29398968,
#          1.4987896 ]])

# %%
model = LinearRegression()

# %%
model.fit(x_train , y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
y_pred
# Out:
# array([2.99361553, 2.88825271, 2.79904958, ..., 2.77061446, 3.16817218,
#        3.32387621])

# %%
mse = np.mean((y_pred - y_test)**2)

# %%
mse
# Out:
# 0.6200525604720908

# %%
rmse = np.sqrt(mse)

# %%
rmse
# Out:
# 0.7874341626270038

# %%
np = ([[0.8206194 ,  1.70289269,  0.43435515, -0.628993  ,  0.74427104,
        -0.32718167]])

prediction = model.predict(np)

# %%
prediction
# Out:
# array([2.90034908])

# %%
rfe = RFE(model , n_features_to_select = 5)

# %%
rfe.fit(x_train , y_train)
# Out:
# RFE(estimator=LinearRegression(), n_features_to_select=5)

# %%
y_rfe = rfe.predict(x_test)

# %%
y_rfe
# Out:
# array([2.98380474, 2.89826418, 2.81399973, ..., 2.78180464, 3.16901559,
#        3.31162193])
